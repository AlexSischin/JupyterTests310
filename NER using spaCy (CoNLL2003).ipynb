# %% [markdown]
# ### 0. Initializing convenience functions

# %%
import spacy
from spacy import displacy

def display_ner(nlp_pipe=None, test_data='./data/CoNLL2003/spacy/test.spacy'):
    base_nlp = spacy.blank('en')
    doc_bin = spacy.tokens.DocBin().from_disk(test_data)
    docs = doc_bin.get_docs(base_nlp.vocab)
    doc = next(docs)
    if nlp_pipe is not None:
        if isinstance(nlp_pipe, str):
            nlp_pipe = spacy.load(nlp_pipe)
        doc = nlp_pipe(doc.text)
    displacy.render(doc, style='ent')
# Out:
# 2023-06-01 23:18:45.837873: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-01 23:18:46.500007: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-01 23:18:47.301413: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-01 23:18:47.301639: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# ...

# %% [markdown]
# ### 1. Converting data from conll2003 format to spacy format.

# %%
!\
cd ./data/CoNLL2003; \
TRAIN_FILE=./spacy/train.spacy; \
VALID_FILE=./spacy/valid.spacy; \
TEST_FILE=./spacy/test.spacy; \
\
if [[ ! -f "$TRAIN_FILE" ]]; then \
    echo "$TRAIN_FILE does not exist, generating..."; \
    python -m spacy convert ./train.txt ./spacy/ -c conll -n 10; \
else \
    echo "$TRAIN_FILE already exists."; \
fi; \
\
if [[ ! -f "$VALID_FILE" ]]; then \
    echo "$VALID_FILE does not exist, generating..."; \
    python -m spacy convert ./valid.txt ./spacy/ -c conll -n 10; \
else \
    echo "$VALID_FILE already exists."; \
fi; \
\
if [[ ! -f "$TEST_FILE" ]]; then \
    echo "$TEST_FILE does not exist, generating..."; \
    python -m spacy convert ./test.txt ./spacy/ -c conll -n 10; \
else \
    echo "$TEST_FILE already exists."; \
fi; \
\
ls -al $TRAIN_FILE; \
ls -al $VALID_FILE; \
ls -al $TEST_FILE
# Out:
# ./spacy/train.spacy already exists.
# ./spacy/valid.spacy already exists.
# ./spacy/test.spacy already exists.
# -rwxrwxrwx 1 alexsis alexsis 1906793 May 31 20:44 ./spacy/train.spacy
# -rwxrwxrwx 1 alexsis alexsis 502856 May 31 20:44 ./spacy/valid.spacy
# -rwxrwxrwx 1 alexsis alexsis 458202 May 31 20:44 ./spacy/test.spacy

# %%
display_ner()
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">-DOCSTART- SOCCER -
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JAPAN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  GET LUCKY WIN ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CHINA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  IN SURPRISE DEFEAT .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nadim Ladki
# ...

# %% [markdown]
# ### 2. Establishing the baseline performance

# %%
# !python -m spacy benchmark accuracy en_core_web_sm ./data/CoNLL2003/spacy/test.spacy

# %% [markdown]
# Output example:

# %% [raw]
# ℹ Using CPU
# ℹ To switch to GPU 0, use the option: --gpu-id 0
#
# ================================== Results ==================================
#
# TOK      -
# TAG      86.82
# POS      -
# MORPH    -
# LEMMA    -
# UAS      -
# LAS      -
# NER P    6.23
# NER R    9.10
# NER F    7.40
# SENT P   53.14
# SENT R   33.79
# SENT F   41.31
# SPEED    12977
#
#
# =============================== NER (per type) ===============================
#
#                   P       R       F
# ORG           43.74   28.84   34.76
# PERSON         0.00    0.00    0.00
# GPE            0.00    0.00    0.00
# EVENT          0.00    0.00    0.00
# DATE           0.00    0.00    0.00
# ORDINAL        0.00    0.00    0.00
# TIME           0.00    0.00    0.00
# NORP           0.00    0.00    0.00
# PER            0.00    0.00    0.00
# MISC           0.00    0.00    0.00
# LOC           44.30    2.10    4.01
# CARDINAL       0.00    0.00    0.00
# MONEY          0.00    0.00    0.00
# LAW            0.00    0.00    0.00
# PERCENT        0.00    0.00    0.00
# QUANTITY       0.00    0.00    0.00
# WORK_OF_ART    0.00    0.00    0.00
# PRODUCT        0.00    0.00    0.00
# FAC            0.00    0.00    0.00
# LANGUAGE       0.00    0.00    0.00

# %%
# !python -m spacy benchmark speed en_core_web_sm ./data/CoNLL2003/spacy/test.spacy

# %% [markdown]
# Example output:

# %% [raw]
# ℹ Using CPU
# ℹ To switch to GPU 0, use the option: --gpu-id 0
# Warming up for 3 epochs...
# 100%|█████████████████████████████████████| 1107/1107 [00:08<00:00, 134.22doc/s]
#
# Benchmarking 50 batches...
# 100%|███████████████████████████████████| 12800/12800 [01:43<00:00, 124.07doc/s]
#
# Outliers: 0.0%, extreme outliers: 0.0%
# Mean: 16558.6 words/s (95% CI: -170.6 +166.8)

# %%
display_ner('en_core_web_sm')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">-DOCSTART- SOCCER - JAPAN GET LUCKY
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     WIN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  , CHINA IN SURPRISE
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DEFEAT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nadim Ladki AL-AIN
# ...

# %% [markdown]
# ### 3. Initializing configs

# %%
!\
cd ./config; \
SM_CFG_FILE=ner_conll2003_sm.cfg; \
XSM_CFG_FILE=ner_conll2003_xsm.cfg; \
\
if [[ ! -f "$SM_CFG_FILE" ]]; then \
    echo "$SM_CFG_FILE does not exist, initializing..."; \
    python -m spacy init config $SM_CFG_FILE -p "tagger,ner" -o "efficiency" -G; \
else \
    echo "$SM_CFG_FILE already exists."; \
fi; \
\
if [[ ! -f "$XSM_CFG_FILE" ]]; then \
    echo "$XSM_CFG_FILE does not exist, initializing..."; \
    python -m spacy init config ner_conll2003_xsm.cfg -p "tagger,ner" -o "efficiency" -G; \
else \
    echo "$XSM_CFG_FILE already exists."; \
fi; \
\
ls -al | grep -E "$SM_CFG_FILE|$XSM_CFG_FILE"
# Out:
# ner_conll2003_sm.cfg already exists.
# ner_conll2003_xsm.cfg already exists.
# -rwxrwxrwx 1 alexsis alexsis 3309 Jun  1 16:22 ner_conll2003_sm.cfg
# -rwxrwxrwx 1 alexsis alexsis 3162 Jun  2  2023 ner_conll2003_xsm.cfg

# %% [markdown]
# ### 4. Training

# %% [markdown]
# #### 4.1. The lightweight model

# %%
!\
MODEL_PATH=model/NER_POS_CoNLL2003_SM; \
if [ -z "$(ls -A $MODEL_PATH)" ]; then \
   echo "Model not found, training"; \
    python -m spacy train ./config/ner_conll2003_sm.cfg \
       --output $MODEL_PATH \
       --paths.train ./data/CoNLL2003/spacy/train.spacy \
       --paths.dev ./data/CoNLL2003/spacy/valid.spacy \
       --gpu-id 0 \
       --verbose; \
else \
   echo "Model already exists"; \
fi; \
ls -al $MODEL_PATH
# Out:
# Model already exists
# total 0
# drwxrwxrwx 1 alexsis alexsis 4096 May 31 21:51 .
# drwxrwxrwx 1 alexsis alexsis 4096 Jun  1 14:46 ..
# drwxrwxrwx 1 alexsis alexsis 4096 May 31 20:52 model-best
# drwxrwxrwx 1 alexsis alexsis 4096 May 31 20:52 model-last

# %% [markdown]
# Output example:

# %% [raw]
# Model not found, training
# [2023-05-31 20:52:12,200] [DEBUG] Config overrides from CLI: ['paths.train', 'paths.dev']
# ℹ Saving to output directory: model/NER_POS_CoNLL2003_SM
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2023-05-31 20:52:14,304] [INFO] Set up nlp object from config
# [2023-05-31 20:52:14,315] [DEBUG] Loading corpus from path: data/CoNLL2003/spacy/valid.spacy
# [2023-05-31 20:52:14,316] [DEBUG] Loading corpus from path: data/CoNLL2003/spacy/train.spacy
# [2023-05-31 20:52:14,316] [INFO] Pipeline: ['transformer', 'tagger', 'ner']
# [2023-05-31 20:52:14,320] [DEBUG] Loading lookups from spacy-lookups-data: ['lexeme_norm']
# [2023-05-31 20:52:14,327] [INFO] Added vocab lookups: lexeme_norm
# [2023-05-31 20:52:14,328] [INFO] Created vocabulary
# [2023-05-31 20:52:14,328] [INFO] Finished initializing nlp object
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [2023-05-31 20:52:24,016] [INFO] Initialized pipeline components: ['transformer', 'tagger', 'ner']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# [2023-05-31 20:52:24,029] [DEBUG] Loading corpus from path: data/CoNLL2003/spacy/valid.spacy
# [2023-05-31 20:52:24,030] [DEBUG] Loading corpus from path: data/CoNLL2003/spacy/train.spacy
# ℹ Pipeline: ['transformer', 'tagger', 'ner']
# ℹ Initial learn rate: 0.0
# E    #       LOSS TRANS...  LOSS TAGGER  LOSS NER  TAG_ACC  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  -------------  -----------  --------  -------  ------  ------  ------  ------
#   0       0         305.44       323.80    413.30     1.24    2.11    1.18   10.23    0.02
#   1     200      233691.97    335575.29  94611.96    51.88   91.10   91.67   90.54    0.71
#   3     400        6123.49    128051.36   5704.79    93.47   94.64   94.42   94.87    0.94
#   5     600        4762.69     26998.98   2940.68    95.02   95.11   95.23   95.00    0.95
#   7     800        4069.71     20016.06   1939.99    95.19   94.94   94.89   94.98    0.95
#   8    1000        3116.53     14583.97   1255.55    95.43   94.95   94.63   95.27    0.95
#  10    1200        2769.00     11442.60    937.49    95.46   95.50   95.34   95.66    0.95
#  12    1400        2129.98      8163.92    705.78    95.51   95.50   95.25   95.76    0.96
#  14    1600        1767.42      6093.93    570.35    95.44   95.57   95.37   95.78    0.96
#  15    1800        1584.50      4570.16    473.91    95.51   95.62   95.44   95.79    0.96
#  17    2000        1926.43      3785.29    479.16    95.69   95.62   95.47   95.78    0.96
#  19    2200        1197.96      2751.60    357.28    95.58   95.67   95.58   95.76    0.96
#  21    2400        1301.55      2097.91    380.56    95.67   95.28   94.91   95.66    0.95
#  22    2600         945.03      1892.96    259.84    95.46   95.38   94.99   95.78    0.95
#  24    2800        1007.07      1628.16    254.86    95.61   95.62   95.38   95.86    0.96
#  26    3000         779.85      1302.64    202.13    95.65   95.48   95.38   95.57    0.96
#  28    3200         979.56      1255.59    205.65    95.68   95.61   95.45   95.76    0.96
#  29    3400         985.82      1107.88    233.39    95.58   95.60   95.30   95.89    0.96
#  31    3600         831.28       911.54    229.41    95.72   95.80   95.58   96.03    0.96
#  33    3800         921.78       928.28    234.09    95.73   95.46   95.17   95.76    0.96
#  35    4000        1010.25       855.93    162.10    95.70   95.44   95.09   95.79    0.96
#  36    4200         631.58       758.57    153.61    95.75   95.42   95.24   95.61    0.96
#  38    4400         571.15       660.53    130.14    95.78   95.61   95.27   95.94    0.96
#  40    4600         570.40       636.42    126.48    95.79   95.66   95.52   95.81    0.96
#  42    4800         638.16       521.89    153.34    95.69   95.49   95.28   95.71    0.96
#  43    5000        3332.83       498.05    194.82    95.75   95.60   95.41   95.79    0.96
#  45    5200         576.13       496.75    128.91    95.73   95.38   95.16   95.61    0.96
# ✔ Saved pipeline to output directory
# model/NER_POS_CoNLL2003_SM/model-last
# total 0
# drwxrwxrwx 1 alexsis alexsis 4096 May 31 21:51 .
# drwxrwxrwx 1 alexsis alexsis 4096 May 31 19:45 ..
# drwxrwxrwx 1 alexsis alexsis 4096 May 31 20:52 model-best
# drwxrwxrwx 1 alexsis alexsis 4096 May 31 20:52 model-last

# %%
# !python -m spacy benchmark accuracy ./model/NER_POS_CoNLL2003_SM/model-best/ ./data/CoNLL2003/spacy/test.spacy --gpu-id 0

# %% [markdown]
# Example output:

# %% [raw]
# ℹ Using GPU: 0
#
# ================================== Results ==================================
#
# TOK     -
# TAG     95.40
# NER P   91.67
# NER R   92.71
# NER F   92.18
# SPEED   6573
#
#
# =============================== NER (per type) ===============================
#
#            P       R       F
# LOC    93.23   94.06   93.64
# PER    96.53   96.23   96.38
# MISC   81.32   84.33   82.80
# ORG    89.93   91.45   90.69

# %%
# !python -m spacy benchmark accuracy ./model/NER_POS_CoNLL2003_SM/model-last/ ./data/CoNLL2003/spacy/test.spacy --gpu-id 0

# %% [markdown]
# Example output:

# %% [raw]
# ℹ Using GPU: 0
#
# ================================== Results ==================================
#
# TOK     -
# TAG     95.46
# NER P   91.73
# NER R   92.55
# NER F   92.14
# SPEED   7214
#
#
# =============================== NER (per type) ===============================
#
#            P       R       F
# LOC    92.68   94.12   93.40
# PER    96.05   96.23   96.14
# MISC   79.37   86.04   82.57
# ORG    92.24   90.13   91.17

# %%
# !python -m spacy benchmark speed ./model/NER_POS_CoNLL2003_SM/model-best/ ./data/CoNLL2003/spacy/test.spacy

# %% [markdown]
# Output example:

# %% [raw]
# ℹ Using CPU
# ℹ To switch to GPU 0, use the option: --gpu-id 0
# Warming up for 3 epochs...
# 100%|██████████████████████████████████████| 1107/1107 [03:00<00:00,  6.14doc/s]
#
# Benchmarking 50 batches...
# 100%|██████████████████████████████████████| 6400/6400 [18:05<00:00,  5.89doc/s]
#
# Outliers: 8.0%, extreme outliers: 0.0%
# Mean: 792.0 words/s (95% CI: -9.4 +9.7)

# %%
display_ner('./model/NER_POS_CoNLL2003_SM/model-best/')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">-DOCSTART- SOCCER -
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JAPAN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  GET LUCKY WIN ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CHINA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  IN SURPRISE DEFEAT .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nadim Ladki
# ...

# %% [markdown]
# #### 4.2. The extra lightweight model

# %%
!\
MODEL_PATH=model/NER_POS_CoNLL2003_XSM; \
if [ -z "$(ls -A $MODEL_PATH)" ]; then \
   echo "Model not found, training"; \
    python -m spacy train ./config/ner_conll2003_xsm.cfg \
       --output $MODEL_PATH \
       --paths.train ./data/CoNLL2003/spacy/train.spacy \
       --paths.dev ./data/CoNLL2003/spacy/valid.spacy \
       --gpu-id -1 \
       --verbose; \
else \
   echo "Model already exists"; \
fi; \
ls -al $MODEL_PATH
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Model already exists
# total 0
# drwxrwxrwx 1 alexsis alexsis 4096 Jun  2  2023 .
# drwxrwxrwx 1 alexsis alexsis 4096 Jun  1 14:46 ..
# drwxrwxrwx 1 alexsis alexsis 4096 Jun  2  2023 model-best
# drwxrwxrwx 1 alexsis alexsis 4096 Jun  2  2023 model-last

# %% [markdown]
# Output example:

# %% [raw]
# Model not found, training
# [2023-06-01 22:19:49,560] [DEBUG] Config overrides from CLI: ['paths.train', 'paths.dev']
# ℹ Saving to output directory: model/NER_POS_CoNLL2003_XSM
# ℹ Using CPU
# ℹ To switch to GPU 0, use the option: --gpu-id 0
#
# =========================== Initializing pipeline ===========================
# [2023-06-01 22:19:50,074] [INFO] Set up nlp object from config
# [2023-06-01 22:19:50,088] [DEBUG] Loading corpus from path: data/CoNLL2003/spacy/valid.spacy
# [2023-06-01 22:19:50,089] [DEBUG] Loading corpus from path: data/CoNLL2003/spacy/train.spacy
# [2023-06-01 22:19:50,090] [INFO] Pipeline: ['tok2vec', 'tagger', 'ner']
# [2023-06-01 22:19:50,094] [DEBUG] Loading lookups from spacy-lookups-data: ['lexeme_norm']
# [2023-06-01 22:19:50,103] [INFO] Added vocab lookups: lexeme_norm
# [2023-06-01 22:19:50,104] [INFO] Created vocabulary
# [2023-06-01 22:19:50,104] [INFO] Finished initializing nlp object
# [2023-06-01 22:19:56,196] [INFO] Initialized pipeline components: ['tok2vec', 'tagger', 'ner']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# [2023-06-01 22:19:56,222] [DEBUG] Loading corpus from path: data/CoNLL2003/spacy/valid.spacy
# [2023-06-01 22:19:56,223] [DEBUG] Loading corpus from path: data/CoNLL2003/spacy/train.spacy
# ℹ Pipeline: ['tok2vec', 'tagger', 'ner']
# ℹ Initial learn rate: 0.0
# E    #       LOSS
# 131   15000      10171.31     19439.66   6846.68    94.72   83.85   84.52   83.19    0.89
# 133   15200      10538.12     19722.74   7083.17    94.73   83.88   84.44   83.32    0.89
# 135   15400      10141.23     19234.22   6696.44    94.74   83.94   84.50   83.39    0.89
# 136   15600      10337.07     19347.27   6965.74    94.76   83.92   84.54   83.31    0.89
# 138   15800      10276.21     19397.17   6775.20    94.77   84.05   84.63   83.47    0.89
# 140   16000      10386.04     19547.36   6659.68    94.79   83.95   84.59   83.32    0.89
# 142   16200      10161.09     19242.46   6678.19    94.78   84.02   84.57   83.47    0.89
# 143   16400      10118.67     19265.27   6616.68    94.77   83.97   84.68   83.27    0.89
# 145   16600      10163.92     18880.00   6681.53    94.77   84.06   84.68   83.44    0.89
# 147   16800      10261.58     19217.79   6660.43    94.77   84.03   84.71   83.36    0.89
# 149   17000      10486.67     19379.08   6757.31    94.78   84.00   84.65   83.36    0.89
# 150   17200      10100.18     18997.92   6602.18    94.78   84.00   84.63   83.39    0.89
# 152   17400      10229.75     19111.93   6521.60    94.78   84.07   84.76   83.39    0.89
# 154   17600      10506.11     19248.42   6608.19    94.80   84.02   84.71   83.34    0.89
# 156   17800      10133.12     18866.67   6409.05    94.79   83.94   84.57   83.32    0.89
# 157   18000      10287.75     19051.22   6584.08    94.80   83.97   84.61   83.34    0.89
# 159   18200      10162.04     18980.90   6424.82    94.79   83.99   84.65   83.34    0.89
# 161   18400      10041.92     18964.06   6495.39    94.80   84.01   84.65   83.37    0.89
# 163   18600      12203.25     18848.32   6495.18    94.81   83.99   84.64   83.36    0.89
# 165   18800       9932.88     18618.21   6385.91    94.79   83.97   84.63   83.32    0.89
# 166   19000       9873.58     18628.68   6247.18    94.80   84.04   84.73   83.37    0.89
# ✔ Saved pipeline to output directory
# model/NER_POS_CoNLL2003_XSM/model-last
# total 0
# drwxrwxrwx 1 alexsis alexsis 4096 Jun  2  2023 .
# drwxrwxrwx 1 alexsis alexsis 4096 Jun  1 14:46 ..
# drwxrwxrwx 1 alexsis alexsis 4096 Jun  2  2023 model-best
# drwxrwxrwx 1 alexsis alexsis 4096 Jun  2  2023 model-last

# %%
# !python -m spacy benchmark accuracy ./model/NER_POS_CoNLL2003_XSM/model-best/ ./data/CoNLL2003/spacy/test.spacy --gpu-id -1

# %% [markdown]
# Output example:

# %% [raw]
# ℹ Using CPU
# ℹ To switch to GPU 0, use the option: --gpu-id 0
#
# ================================== Results ==================================
#
# TOK     -
# TAG     94.46
# NER P   77.48
# NER R   77.00
# NER F   77.24
# SPEED   56637
#
#
# =============================== NER (per type) ===============================
#
#            P       R       F
# LOC    84.85   82.91   83.87
# ORG    70.53   71.88   71.20
# MISC   70.89   69.37   70.12
# PER    80.16   79.47   79.81

# %%
# !python -m spacy benchmark speed ./model/NER_POS_CoNLL2003_XSM/model-best/ ./data/CoNLL2003/spacy/test.spacy

# %% [markdown]
# Output example:

# %% [raw]
# ℹ Using CPU
# ℹ To switch to GPU 0, use the option: --gpu-id 0
# Warming up for 3 epochs...
# 100%|█████████████████████████████████████| 1107/1107 [00:01<00:00, 665.25doc/s]
#
# Benchmarking 50 batches...
# 100%|█████████████████████████████████████| 6400/6400 [00:10<00:00, 609.15doc/s]
#
# Outliers: 2.0%, extreme outliers: 2.0%
# Mean: 80683.0 words/s (95% CI: -853.8 +684.2)

# %%
display_ner('./model/NER_POS_CoNLL2003_XSM/model-best/')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">-DOCSTART- SOCCER -
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JAPAN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GET
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  LUCKY WIN ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CHINA
# ...
